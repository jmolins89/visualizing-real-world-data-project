# %%
import pandas as pd
import re
import requests

# %%
from pymongo import MongoClient

client = MongoClient('mongodb://localhost:27017/')
db = client.companies

# %%
df = db.companies

# %%
companies_with_coord = pd.DataFrame(df.find(
    {'$and': 
     [
         {"offices.latitude": 
          {'$exists': True}
         },
         {"offices.longitude": 
          {'$exists': True}
         },
         {"offices.latitude": 
          {'$not': 
           {'$eq': None}
          }
         },
         {"offices.longitude": 
          {'$not': 
           {'$eq': None}
          }
         }
     ]
    }))

# %%
display(companies_with_coord.head())
# Out:
#                         _id  \
# 0  52cdef7c4bab8bd675297d8b
# 1  52cdef7c4bab8bd675297d8a
# 2  52cdef7c4bab8bd675297d8c
# 3  52cdef7c4bab8bd675297d8d
# 4  52cdef7c4bab8bd675297d90
#
#                                          acquisition  \
# 0                                               None
# 1  {'price_amount': 30000000, 'price_currency_cod...
# 2                                               None
# 3  {'price_amount': 500000, 'price_currency_code'...
# 4  {'price_amount': 625000000, 'price_currency_co...
#
#                                         acquisitions          alias_list  \
# 0                                                 []  Zoho ManageEngine
# 1                                                 []
# 2                                                 []
# 3  [{'price_amount': None, 'price_currency_code':...
# 4                                                 []                None
#
#                       blog_feed_url                     blog_url  \
# 0
# 1  http://digitalquarters.net/feed/  http://digitalquarters.net/
# 2        http://blogs.zoho.com/feed       http://blogs.zoho.com/
# 3   http://blog.digg.com/?feed=rss2        http://blog.digg.com/
# 4
#
#   category_code                                       competitions  \
# 0    enterprise                                                 []
# 1           web  [{'competitor': {'name': 'Wikia', 'permalink':...
# 2      software  [{'competitor': {'name': 'Empressr', 'permalin...
# 3          news  [{'competitor': {'name': 'Reddit', 'permalink'...
# 4           web  [{'competitor': {'name': 'RescueTime', 'permal...
#
#                      created_at                               crunchbase_url  \
# 0           2007-05-25 19:24:22  http://www.crunchbase.com/company/adventnet
# 1           2007-05-25 06:51:27   http://www.crunchbase.com/company/wetpaint
# 2  Fri May 25 19:30:28 UTC 2007       http://www.crunchbase.com/company/zoho
# 3  Fri May 25 20:03:23 UTC 2007       http://www.crunchbase.com/company/digg
# 4  Fri Jun 08 12:19:51 UTC 2007    http://www.crunchbase.com/company/postini
#
#    ...    phone_number                                           products  \
# 0  ...    925-924-9500                                                 []
# 1  ...    206.859.6300  [{'name': 'Wikison Wetpaint', 'permalink': 'we...
# 2  ...  1-888-204-3539  [{'name': 'Zoho Office Suite', 'permalink': 'z...
# 3  ...  (415) 436-9638            [{'name': 'Digg', 'permalink': 'digg'}]
# 4  ...    888.584.3150  [{'name': 'Postini Solutions', 'permalink': 'p...
#
#                                        providerships  \
# 0  [{'title': 'DHFH', 'is_past': True, 'provider'...
# 1                                                 []
# 2                                                 []
# 3  [{'title': 'Public Relations', 'is_past': True...
# 4                                                 []
#
#                                        relationships  \
# 0  [{'is_past': True, 'title': 'CEO and Co-Founde...
# 1  [{'is_past': False, 'title': 'Co-Founder and V...
# 2  [{'is_past': False, 'title': 'CEO and Founder'...
# 3  [{'is_past': False, 'title': 'CEO', 'person': ...
# 4  [{'is_past': False, 'title': 'Board', 'person'...
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[150, 94], 'assets/imag...
# 1  [{'available_sizes': [[[150, 86], 'assets/imag...
# 2                                                 []
# 3  [{'available_sizes': [[[117, 150], 'assets/ima...
# 4                                                 []
#
#                                             tag_list total_money_raised  \
# 0                                                                    $0
# 1  wiki, seattle, elowitz, media-industry, media-...             $39.8M
# 2  zoho, officesuite, spreadsheet, writer, projec...                 $0
# 3  community, social, news, bookmark, digg, techn...               $45M
# 4                                                                    $0
#
#    twitter_username                    updated_at  \
# 0      manageengine  Wed Oct 31 18:26:09 UTC 2012
# 1   BachelrWetpaint  Sun Dec 08 07:15:44 UTC 2013
# 2              zoho  Wed Oct 30 00:07:05 UTC 2013
# 3              digg  Tue Nov 05 21:35:47 UTC 2013
# 4              None  Sat Aug 13 18:02:34 UTC 2011
#
#                                         video_embeds
# 0                                                 []
# 1                                                 []
# 2  [{'embed_code': '<object width="430" height="2...
# 3  [{'embed_code': '<embed src="http://blip.tv/pl...
# 4                                                 []
#
# [5 rows x 42 columns]

# %%
letters=[]
for i in companies_with_coord['total_money_raised']:
    if re.findall('[^0-9.,]+',i) not in letters:
        letters.append(re.findall('[^0-9.,]+',i))

# %%
letters
# Out:
# [['$'],
#  ['$', 'M'],
#  ['$', 'B'],
#  ['$', 'k'],
#  ['€', 'k'],
#  ['€', 'M'],
#  ['£', 'k'],
#  ['£', 'M'],
#  ['C$', 'M'],
#  ['C$', 'k'],
#  ['kr', 'M']]

# %%
dict_coin={
    '$' : 'USD',
    '£' : 'GBP',
    'C$' : 'CAD',
    'kr' : 'SEK',
    '€' : 'EUR'
}
coins= ['USD','GBP','CAD','SEK']

# %%
coindict={}
for i in coins:
    res = requests.get('https://api.exchangeratesapi.io/latest')
    data = res.json()
    coindict[i] = data['rates'][i]

# %%
coindict
# Out:
# {'USD': 1.1215, 'GBP': 0.89625, 'CAD': 1.4642, 'SEK': 10.5973}

# %%
dict_quantity={
    '$': 1,
    'M': 1000000, 
    'B':1000000000, 
    'k': 1000, 
    '£':0.89625/1.1215,  
    'C$':1.4642/1.1215, 
    'kr':10.5973/1.1215,
    '€':1/1.1215
}

# %%
dict_quantity['$']
# Out:
# 1

# %%
total_money_raised_normalized=[]
for i in companies_with_coord['total_money_raised']:
    x = float(re.findall('[0-9.]+',str(i))[0])
    y=1
    for j in re.findall('[^0-9.]+',str(i)):
        y = y* dict_quantity[j]
    total_money_raised_normalized.append(x*y)

# %%
len(total_money_raised_normalized)
# Out:
# 9025

# %%
companies_with_coord['total_money_raised_normalized_USD']= total_money_raised_normalized

# %%
for i in companies_with_coord['offices'].head():
    print(len(i))
# Out:
# 1
# 2
# 1
# 1
# 1

# %%
companies_with_coord_intermediate=companies_with_coord.drop(columns='offices')

# %%
office_list=[]
for i in companies_with_coord['offices']:
    if not isinstance(i,list):
        office_list.append(list(i))
    else: office_list.append(i)

# %%
#companies_with_coord['offices']=office_list

# %%
companies_with_coord2 = pd.DataFrame(companies_with_coord.offices.tolist()).stack().reset_index().drop(columns='level_1')
companies_with_coord2.columns=['index','office']

# %%
display(companies_with_coord2.head())
# Out:
#    index                                             office
# 0      0  {'description': 'Headquarters', 'address1': '4...
# 1      1  {'description': '', 'address1': '710 - 2nd Ave...
# 2      1  {'description': '', 'address1': '270 Lafayette...
# 3      2  {'description': 'Headquarters', 'address1': '4...
# 4      3  {'description': None, 'address1': '135 Mississ...

# %%
companies_with_coord.reset_index(inplace=True)

# %%
companies_with_coord.head()
# Out:
#    index                       _id  \
# 0      0  52cdef7c4bab8bd675297d8b
# 1      1  52cdef7c4bab8bd675297d8a
# 2      2  52cdef7c4bab8bd675297d8c
# 3      3  52cdef7c4bab8bd675297d8d
# 4      4  52cdef7c4bab8bd675297d90
#
#                                          acquisition  \
# 0                                               None
# 1  {'price_amount': 30000000, 'price_currency_cod...
# 2                                               None
# 3  {'price_amount': 500000, 'price_currency_code'...
# 4  {'price_amount': 625000000, 'price_currency_co...
#
#                                         acquisitions          alias_list  \
# 0                                                 []  Zoho ManageEngine
# 1                                                 []
# 2                                                 []
# 3  [{'price_amount': None, 'price_currency_code':...
# 4                                                 []                None
#
#                       blog_feed_url                     blog_url  \
# 0
# 1  http://digitalquarters.net/feed/  http://digitalquarters.net/
# 2        http://blogs.zoho.com/feed       http://blogs.zoho.com/
# 3   http://blog.digg.com/?feed=rss2        http://blog.digg.com/
# 4
#
#   category_code                                       competitions  \
# 0    enterprise                                                 []
# 1           web  [{'competitor': {'name': 'Wikia', 'permalink':...
# 2      software  [{'competitor': {'name': 'Empressr', 'permalin...
# 3          news  [{'competitor': {'name': 'Reddit', 'permalink'...
# 4           web  [{'competitor': {'name': 'RescueTime', 'permal...
#
#                      created_at  ...  \
# 0           2007-05-25 19:24:22  ...
# 1           2007-05-25 06:51:27  ...
# 2  Fri May 25 19:30:28 UTC 2007  ...
# 3  Fri May 25 20:03:23 UTC 2007  ...
# 4  Fri Jun 08 12:19:51 UTC 2007  ...
#
#                                             products  \
# 0                                                 []
# 1  [{'name': 'Wikison Wetpaint', 'permalink': 'we...
# 2  [{'name': 'Zoho Office Suite', 'permalink': 'z...
# 3            [{'name': 'Digg', 'permalink': 'digg'}]
# 4  [{'name': 'Postini Solutions', 'permalink': 'p...
#
#                                        providerships  \
# 0  [{'title': 'DHFH', 'is_past': True, 'provider'...
# 1                                                 []
# 2                                                 []
# 3  [{'title': 'Public Relations', 'is_past': True...
# 4                                                 []
#
#                                        relationships  \
# 0  [{'is_past': True, 'title': 'CEO and Co-Founde...
# 1  [{'is_past': False, 'title': 'Co-Founder and V...
# 2  [{'is_past': False, 'title': 'CEO and Founder'...
# 3  [{'is_past': False, 'title': 'CEO', 'person': ...
# 4  [{'is_past': False, 'title': 'Board', 'person'...
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[150, 94], 'assets/imag...
# 1  [{'available_sizes': [[[150, 86], 'assets/imag...
# 2                                                 []
# 3  [{'available_sizes': [[[117, 150], 'assets/ima...
# 4                                                 []
#
#                                             tag_list total_money_raised  \
# 0                                                                    $0
# 1  wiki, seattle, elowitz, media-industry, media-...             $39.8M
# 2  zoho, officesuite, spreadsheet, writer, projec...                 $0
# 3  community, social, news, bookmark, digg, techn...               $45M
# 4                                                                    $0
#
#   twitter_username                    updated_at  \
# 0     manageengine  Wed Oct 31 18:26:09 UTC 2012
# 1  BachelrWetpaint  Sun Dec 08 07:15:44 UTC 2013
# 2             zoho  Wed Oct 30 00:07:05 UTC 2013
# 3             digg  Tue Nov 05 21:35:47 UTC 2013
# 4             None  Sat Aug 13 18:02:34 UTC 2011
#
#                                         video_embeds  \
# 0                                                 []
# 1                                                 []
# 2  [{'embed_code': '<object width="430" height="2...
# 3  [{'embed_code': '<embed src="http://blip.tv/pl...
# 4                                                 []
#
#    total_money_raised_normalized_USD
# 0                                0.0
# 1                         39800000.0
# 2                                0.0
# 3                         45000000.0
# 4                                0.0
#
# [5 rows x 44 columns]

# %%
companies_with_coord_offices= companies_with_coord2.merge(companies_with_coord, how='left', on='index')

# %%
companies_with_coord_offices.columns
# Out:
# Index(['index', 'office', '_id', 'acquisition', 'acquisitions', 'alias_list',
#        'blog_feed_url', 'blog_url', 'category_code', 'competitions',
#        'created_at', 'crunchbase_url', 'deadpooled_day', 'deadpooled_month',
#        'deadpooled_url', 'deadpooled_year', 'description', 'email_address',
#        'external_links', 'founded_day', 'founded_month', 'founded_year',
#        'funding_rounds', 'homepage_url', 'image', 'investments', 'ipo',
#        'milestones', 'name', 'number_of_employees', 'offices', 'overview',
#        'partners', 'permalink', 'phone_number', 'products', 'providerships',
#        'relationships', 'screenshots', 'tag_list', 'total_money_raised',
#        'twitter_username', 'updated_at', 'video_embeds',
#        'total_money_raised_normalized_USD'],
#       dtype='object')

# %%
def getFirst(data):
    data = data['office']
#    return (len(data),data[0]['latitude'],data[0]['longitude'])

    # Only create the geoJSON object if all geodata is available
    principal = None
    if data['latitude'] and data['longitude']:
        principal = {
            "type":"Point",
            "coordinates":[data['longitude'], data['latitude']]
        }

    return {
        "lat": data['latitude'],
        "lng": data['longitude'],
        "oficina_principal": principal
    }

# %%
companies_with_coord_offices_sub = companies_with_coord_offices[["office"]].apply(getFirst, result_type="expand", axis=1)

# %%
companies_with_coord_offices_sub.head()
# Out:
#          lat         lng                                  oficina_principal
# 0  37.692934 -121.904945  {'type': 'Point', 'coordinates': [-121.904945,...
# 1  47.603122 -122.333253  {'type': 'Point', 'coordinates': [-122.333253,...
# 2  40.723731  -73.996431  {'type': 'Point', 'coordinates': [-73.9964312,...
# 3  37.692934 -121.904945  {'type': 'Point', 'coordinates': [-121.904945,...
# 4  37.764726 -122.394523  {'type': 'Point', 'coordinates': [-122.394523,...

# %%
companies_with_coord_offices_clean = pd.concat([companies_with_coord_offices,companies_with_coord_offices_sub], axis=1)

# %%
companies_with_coord_offices_clean.head()
# Out:
#    index                                             office  \
# 0      0  {'description': 'Headquarters', 'address1': '4...
# 1      1  {'description': '', 'address1': '710 - 2nd Ave...
# 2      1  {'description': '', 'address1': '270 Lafayette...
# 3      2  {'description': 'Headquarters', 'address1': '4...
# 4      3  {'description': None, 'address1': '135 Mississ...
#
#                         _id  \
# 0  52cdef7c4bab8bd675297d8b
# 1  52cdef7c4bab8bd675297d8a
# 2  52cdef7c4bab8bd675297d8a
# 3  52cdef7c4bab8bd675297d8c
# 4  52cdef7c4bab8bd675297d8d
#
#                                          acquisition  \
# 0                                               None
# 1  {'price_amount': 30000000, 'price_currency_cod...
# 2  {'price_amount': 30000000, 'price_currency_cod...
# 3                                               None
# 4  {'price_amount': 500000, 'price_currency_code'...
#
#                                         acquisitions          alias_list  \
# 0                                                 []  Zoho ManageEngine
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'price_amount': None, 'price_currency_code':...
#
#                       blog_feed_url                     blog_url  \
# 0
# 1  http://digitalquarters.net/feed/  http://digitalquarters.net/
# 2  http://digitalquarters.net/feed/  http://digitalquarters.net/
# 3        http://blogs.zoho.com/feed       http://blogs.zoho.com/
# 4   http://blog.digg.com/?feed=rss2        http://blog.digg.com/
#
#   category_code                                       competitions  ...  \
# 0    enterprise                                                 []  ...
# 1           web  [{'competitor': {'name': 'Wikia', 'permalink':...  ...
# 2           web  [{'competitor': {'name': 'Wikia', 'permalink':...  ...
# 3      software  [{'competitor': {'name': 'Empressr', 'permalin...  ...
# 4          news  [{'competitor': {'name': 'Reddit', 'permalink'...  ...
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[150, 94], 'assets/imag...
# 1  [{'available_sizes': [[[150, 86], 'assets/imag...
# 2  [{'available_sizes': [[[150, 86], 'assets/imag...
# 3                                                 []
# 4  [{'available_sizes': [[[117, 150], 'assets/ima...
#
#                                             tag_list  total_money_raised  \
# 0                                                                     $0
# 1  wiki, seattle, elowitz, media-industry, media-...              $39.8M
# 2  wiki, seattle, elowitz, media-industry, media-...              $39.8M
# 3  zoho, officesuite, spreadsheet, writer, projec...                  $0
# 4  community, social, news, bookmark, digg, techn...                $45M
#
#    twitter_username                    updated_at  \
# 0      manageengine  Wed Oct 31 18:26:09 UTC 2012
# 1   BachelrWetpaint  Sun Dec 08 07:15:44 UTC 2013
# 2   BachelrWetpaint  Sun Dec 08 07:15:44 UTC 2013
# 3              zoho  Wed Oct 30 00:07:05 UTC 2013
# 4              digg  Tue Nov 05 21:35:47 UTC 2013
#
#                                         video_embeds  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [{'embed_code': '<object width="430" height="2...
# 4  [{'embed_code': '<embed src="http://blip.tv/pl...
#
#   total_money_raised_normalized_USD        lat         lng  \
# 0                               0.0  37.692934 -121.904945
# 1                        39800000.0  47.603122 -122.333253
# 2                        39800000.0  40.723731  -73.996431
# 3                               0.0  37.692934 -121.904945
# 4                        45000000.0  37.764726 -122.394523
#
#                                    oficina_principal
# 0  {'type': 'Point', 'coordinates': [-121.904945,...
# 1  {'type': 'Point', 'coordinates': [-122.333253,...
# 2  {'type': 'Point', 'coordinates': [-73.9964312,...
# 3  {'type': 'Point', 'coordinates': [-121.904945,...
# 4  {'type': 'Point', 'coordinates': [-122.394523,...
#
# [5 rows x 48 columns]

# %%
companies_with_coord_offices_clean.columns

# %%
companies_with_coord_offices_clean_final = companies_with_coord_offices_clean.drop(columns=['index','alias_list','blog_feed_url','blog_url','crunchbase_url','deadpooled_url','external_links','homepage_url','image','offices','permalink','twitter_username','video_embeds'])

# %%
companies_with_coord_offices_clean_final.to_json('data_clean.json', orient="records")
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-57-c6a8d5b82166> in <module>
# ----> 1 companies_with_coord_offices_clean_final.to_json('data_clean.json', orient="records")
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/generic.py in to_json(self, path_or_buf, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index)
#    2271                             default_handler=default_handler,
#    2272                             lines=lines, compression=compression,
# -> 2273                             index=index)
#    2274
#    2275     def to_hdf(self, path_or_buf, key, **kwargs):
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/json/json.py in to_json(path_or_buf, obj, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index)
#      60         double_precision=double_precision, ensure_ascii=force_ascii,
#      61         date_unit=date_unit, default_handler=default_handler,
# ---> 62         index=index).write()
#      63
#      64     if lines:
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/json/json.py in write(self)
#     102         return self._write(self.obj, self.orient, self.double_precision,
#     103                            self.ensure_ascii, self.date_unit,
# --> 104                            self.date_format == 'iso', self.default_handler)
#     105
#     106     def _write(self, obj, orient, double_precision, ensure_ascii,
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/json/json.py in _write(self, obj, orient, double_precision, ensure_ascii, date_unit, iso_dates, default_handler)
#     159                                                double_precision,
#     160                                                ensure_ascii, date_unit,
# --> 161                                                iso_dates, default_handler)
#     162
#     163
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/json/json.py in _write(self, obj, orient, double_precision, ensure_ascii, date_unit, iso_dates, default_handler)
#     113             date_unit=date_unit,
#     114             iso_dates=iso_dates,
# --> 115             default_handler=default_handler
#     116         )
#     117
#
# OverflowError: Overlong 2 byte UTF-8 sequence detected when encoding string
